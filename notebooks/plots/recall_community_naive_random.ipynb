# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import h5py
import seaborn
import numpy as np
import os
import tensorflow as tf
from sklearn.metrics import pairwise_distances
import sys
sys.path.append("../")
from utils import l2_normalize, prewhiten, read_sampled_identities, plot_recall, recall_given_dist, plot_topk
from PIL import Image
seaborn.set()

# %%
attack_name = "community_naive_random"

kwargs = {
    "attack_name": attack_name,
    "path_to_adversarial": "/data/vggface/test_perturbed_sampled/{true}/" + attack_name + "/{target}/epsilon_{epsilon}.h5",
    "path_to_clean": "/data/vggface/test_preprocessed_sampled/{id}/embeddings.h5",
#     "epsilons": [0.0, 0.02, 0.04, 0.06, 0.08, 0.1],
    "epsilons": [0.0, 0.02, 0.06, 0.08, 0.1],
    "identities": read_sampled_identities("../sampled_identities.txt").keys(),
}

kwargs_topk = kwargs.copy()
del kwargs_topk["attack_name"]
del kwargs_topk["epsilons"]

# %%
plot_recall(
    ks=[1, 5, 10, 50, 100],
    colors=['#0017ad', '#2d67ed', '#37a0f0', '#37e6f0','#000000'],
    mode="recall",
    attack_plot_name="Recall when targeting a randomly sampled lookup set vector",
    **kwargs
)

# %%
plot_recall(
    ks=[1, 5, 10, 100],
    colors=['#9c0000',
            '#c41010',
            '#d64f1a',
            '#eb8028'],
    mode="discovery",
    attack_plot_name = "Discovery when targeting a randomly sampled lookup set vector",
    **kwargs
)

# %%
plot_recall(
    ks=[50, 100],
    colors=['#845ec2', '#d65db1', '#ff6f91', '#ff9671', '#ffc75f', '#f9f871'],
    mode="identropy",
    attack_plot_name="Identity variation when targeting a randomly sampled lookup set vector",
    **kwargs
)

# %%
# plot_topk(
#     adversarial_target="n005359", 
#     epsilon=0.04,
#     mode="discovery",
#     k=100,
#     **kwargs_topk
# )

# %%
# attack_name = "community_naive_random"

# kwargs = {
#     "attack_name": attack_name,
#     "path_to_adversarial": "/data/vggface/test_perturbed_sampled/{true}/" + attack_name + "/{target}/epsilon_{epsilon}/jpeg",
#     "path_to_clean": "/data/vggface/test_preprocessed_sampled/{id}/embeddings.h5",
# #     "epsilons": [0.0, 0.02, 0.04, 0.06, 0.08, 0.1],
#     "epsilons": [0.0, 0.02, 0.06, 0.08, 0.1],
#     "identities": read_sampled_identities("../sampled_identities.txt").keys(),
#     'model_path': '../keras-facenet/model/facenet_keras.h5'
# }

# plot_recall(
#     ks=[1, 5, 10, 100, 1000],
#     colors=['#0017ad', '#2d67ed', '#37a0f0', '#37e6f0','#000000'],
#     mode="recall",
#     **kwargs
# )

# %%
# attack_name = "community_naive_random"

# kwargs = {
#     "attack_name": attack_name,
#     "path_to_adversarial": "/data/vggface/test_perturbed_sampled/{true}/" + attack_name + "/{target}/epsilon_{epsilon}/bmp",
#     "path_to_clean": "/data/vggface/test_preprocessed_sampled/{id}/embeddings.h5",
# #     "epsilons": [0.0, 0.02, 0.04, 0.06, 0.08, 0.1],
#     "epsilons": [0.0, 0.02, 0.06, 0.08, 0.1],
#     "identities": read_sampled_identities("../sampled_identities.txt").keys(),
#     'model_path': '../keras-facenet/model/facenet_keras.h5'
# }

# plot_recall(
#     ks=[1, 5, 10, 100, 1000],
#     colors=['#0017ad', '#2d67ed', '#37a0f0', '#37e6f0','#000000'],
#     mode="recall",
#     **kwargs
# )

# %%
# attack_name = "community_naive_random"

# kwargs = {
#     "attack_name": attack_name,
#     "path_to_adversarial": "/data/vggface/test_perturbed_sampled/{true}/" + attack_name + "/{target}/epsilon_{epsilon}/jpeg",
#     "path_to_clean": "/data/vggface/test_preprocessed_sampled/{id}/embeddings.h5",
# #     "epsilons": [0.0, 0.02, 0.04, 0.06, 0.08, 0.1],
#     "epsilons": [0.0, 0.02, 0.06, 0.08, 0.1],
#     "identities": read_sampled_identities("../sampled_identities.txt").keys(),
#     'model_path': '../keras-facenet/model/facenet_keras.h5'
# }
# kwargs_topk = kwargs.copy()
# del kwargs_topk["attack_name"]
# del kwargs_topk["epsilons"]

# plot_topk(
#     adversarial_target="n005359", 
#     epsilon=0.1,
#     mode="discovery",
#     k=100,
#     **kwargs_topk
# )
